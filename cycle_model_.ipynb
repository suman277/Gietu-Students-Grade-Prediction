# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\Suman\Desktop\GIET STUDENT'S  MARK PRED\CTPRED.csv")

# %%
data
# Out:
#      CT1 SEM1  CT2 SEM1  CT1 SEM2  CT2 SEM2  CT1 SEM3  CT2 SEM3  CT1 SEM4  \
# 0         119        79       144        74       115       112        78
# 1          56       152        58        89        96        32        58
# 2         131       123        88       162       177       113        82
# 3          33        99       101       124        85       117        87
# 4          33        39       128        73        86       138       129
# ..        ...       ...       ...       ...       ...       ...       ...
# 375        39       113        74        54       125       115        45
# 376       149       138        35        96       178        48        42
# 377        85        60       147       126        34       128        89
# 378       175       124        41        57        87        62        33
# 379        94        69       117       107       121        36       148
#
#      CT2 SEM4  CT1 SEM5
# 0          68     98.63
# 1          32     71.63
# ...

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#          CT1 SEM1    CT2 SEM1    CT1 SEM2    CT2 SEM2    CT1 SEM3    CT2 SEM3  \
# count  380.000000  380.000000  380.000000  380.000000  380.000000  380.000000
# mean   106.615789  105.242105  104.210526  104.610526  106.178947  100.444737
# std     42.904936   43.265082   41.903935   41.881298   43.199782   42.358934
# min     30.000000   30.000000   30.000000   30.000000   31.000000   30.000000
# 25%     70.000000   68.750000   72.000000   70.000000   69.000000   64.750000
# 50%    107.500000  105.000000  101.000000  104.000000  105.000000   99.500000
# 75%    144.250000  141.000000  139.000000  138.000000  145.000000  135.000000
# max    180.000000  180.000000  180.000000  180.000000  180.000000  180.000000
#
#          CT1 SEM4    CT2 SEM4    CT1 SEM5
# count  380.000000  380.000000  380.000000
# mean   105.689474  104.692105  104.713263
# std     43.491526   43.115265   15.516385
# min     30.000000   30.000000   58.380000
# 25%     69.000000   67.000000   94.220000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CT1 SEM1  380 non-null    int64
#  1   CT2 SEM1  380 non-null    int64
#  2   CT1 SEM2  380 non-null    int64
#  3   CT2 SEM2  380 non-null    int64
#  4   CT1 SEM3  380 non-null    int64
#  5   CT2 SEM3  380 non-null    int64
#  6   CT1 SEM4  380 non-null    int64
#  7   CT2 SEM4  380 non-null    int64
#  8   CT1 SEM5  380 non-null    float64
# dtypes: float64(1), int64(8)
# memory usage: 26.8 KB

# %%
sns.pairplot(data)
plt.show()

# %%
data1=data.corr()

# %%
sns.heatmap(data1)
# Out:
# <AxesSubplot:>

# %%
data.sum()
# Out:
# CT1 SEM1    40514.00
# CT2 SEM1    39992.00
# CT1 SEM2    39600.00
# CT2 SEM2    39752.00
# CT1 SEM3    40348.00
# CT2 SEM3    38169.00
# CT1 SEM4    40162.00
# CT2 SEM4    39783.00
# CT1 SEM5    39791.04
# dtype: float64

# %%
data.mean()
# Out:
# CT1 SEM1    106.615789
# CT2 SEM1    105.242105
# CT1 SEM2    104.210526
# CT2 SEM2    104.610526
# CT1 SEM3    106.178947
# CT2 SEM3    100.444737
# CT1 SEM4    105.689474
# CT2 SEM4    104.692105
# CT1 SEM5    104.713263
# dtype: float64

# %%
X=data.drop("CT1 SEM5", axis=1)

# %%
y=data['CT1 SEM5']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.3, random_state=3)

# %%
print("Shape of X_train=", X_train.shape)
print("Shape of X_test", X_test.shape)
print("shape of y_train=",y_train.shape)
print("Shape of y_test", y_test.shape)
# Out:
# Shape of X_train= (266, 8)
# Shape of X_test (114, 8)
# shape of y_train= (266,)
# Shape of y_test (114,)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.predict(X_test)
# Out:
# array([ 91.87730515,  97.00263513, 130.12809105,  83.50257166,
#        103.87805185,  87.50238737, 105.37751858,  90.5031555 ,
#        109.12755339, 108.2534148 ,  85.62801684, 108.87735719,
#        109.87720982, 112.00290364, 102.62813861,  95.37779214,
#        100.25242226, 100.00299861,  94.12781915,  94.75310036,
#        119.62768672, 110.12760019,  84.25266564,  95.25302293,
#         93.00274033,  95.25207295, 117.75268312,  91.87797245,
#         99.12815358,  62.75314684, 120.00233534,  94.87728754,
#        123.00225228, 101.00275444, 110.37709548, 110.87841465,
#        111.37726485, 105.75311658,  97.75320819, 132.62741299,
#         80.87734864, 109.87742887,  95.12769047, 112.75273129,
#        123.37814578, 102.75281   , 100.00303791, 127.62761654,
#         85.753356  ,  77.37794198,  84.12748358, 101.12831392,
#        124.75261881, 116.0029224 ,  96.50260045,  95.25228011,
#        100.12780595, 134.87754172,  92.75317753, 133.37720703,
# ...

# %%
lr.score(X_test, y_test)*100
# Out:
# 99.99999738218297

# %%
from sklearn.linear_model import Lasso, Ridge

# %%
l=Lasso()

# %%
l.fit(X_train, y_train)
# Out:
# Lasso()

# %%
l.fit(X_train, y_train)
# Out:
# Lasso()

# %%
l.score(X_train, y_train)
# Out:
# 0.9999812358459048

# %%
r=Ridge()

# %%
r.fit(X_train, y_train)
# Out:
# Ridge()

# %%
r.score(X_train, y_train)
# Out:
# 0.9999999741133613

# %%
from sklearn.svm import SVR

# %%
svr_rbf = SVR(kernel='rbf')
svr_rbf.fit(X_train, y_train)
svr_rbf.score(X_test, y_test)
# Out:
# 0.7567345167438784

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
regressor = DecisionTreeRegressor(criterion='mse')
regressor.fit(X_train, y_train)
# Out:
# C:\Users\Suman\anaconda3\lib\site-packages\sklearn\tree\_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# DecisionTreeRegressor(criterion='mse')

# %%
regressor.score(X_test, y_test)
# Out:
# 0.38295339952874285

# %%
import pickle

# %%
filename = 'cycle_model.sav'
pickle.dump(lr, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open('cycle_model.sav', 'rb'))

# %%
new_input = pd.DataFrame({'CT1 SEM1': [4.92], 'CT2 SEM1': [4.8], 'CT1 SEM2': [9.909092], 'CT2 SEM2': [3.365],'CT1 SEM3': [9.909092],'CT2 SEM3': [9.909092],'CT1 SEM4': [9.909092],'CT2 SEM4': [9.909092] })

# Make a prediction for the new input
pred = lr.predict(new_input)
# Print the predicted value
pred
# Out:
# array([7.83225575])
